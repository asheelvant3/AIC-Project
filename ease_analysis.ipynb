# %%
# !unzip daisyRec.zip
# Out:
# Archive:  daisyRec.zip
#    creating: daisyRec/
#   inflating: daisyRec/.DS_Store
#   inflating: __MACOSX/daisyRec/._.DS_Store
#    creating: daisyRec/daisy/
#   inflating: daisyRec/LICENSE
#   inflating: daisyRec/requirements.txt
#   inflating: __MACOSX/daisyRec/._requirements.txt
#    creating: daisyRec/images/
#   inflating: daisyRec/Untitled.ipynb
#    creating: daisyRec/run_examples/
#   inflating: daisyRec/README.md
#   inflating: __MACOSX/daisyRec/._README.md
#   inflating: daisyRec/setup.py
#   inflating: __MACOSX/daisyRec/._setup.py
#   inflating: daisyRec/.gitignore
#    creating: daisyRec/.ipynb_checkpoints/
#    creating: daisyRec/.git/
#    creating: daisyRec/data/
#    creating: daisyRec/.idea/
#   inflating: daisyRec/daisy/.DS_Store
#   inflating: __MACOSX/daisyRec/daisy/._.DS_Store
#   inflating: daisyRec/daisy/__init__.py
#   inflating: __MACOSX/daisyRec/daisy/.___init__.py
#    creating: daisyRec/daisy/utils/
#    creating: daisyRec/daisy/model/
# ...

# %%
pip install daisyRec
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for daisyRec: filename=daisyRec-2.3.0-py3-none-any.whl size=51184 sha256=b8edd02cefaed49274687feb2a6ff14a07d19b3c0c6f94e45ef1ca2dc90128a6
#   Stored in directory: /root/.cache/pip/wheels/c4/a1/89/c6af702ab1202cfdcc96ef2c9d7669153e5a5099b321897acf
# Successfully built daisyRec
# ...

# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Amazon - 100K dataset**

# %%
# %%shell
# python /content/daisyRec/run_examples/tune.py --optimization_metric=ndcg --hyperopt_trail=20 --algo_name=ease --dataset=amazon-electronic --prepro=origin --topk=1 --epochs=100 --test_size=0.2 --val_size=0.1 --cand_num=200 --test_method=tsbr --val_method=tsbr --tune_pack='{"reg": {"min": 10, "max": 1000, "step": 10}}'
# Out:
# 17 Apr 05:20 INFO - {'gpu': '0', 'seed': 2022, 'reproducibility': True, 'state': None, 'optimization_metric': 'ndcg', 'hyperopt_trail': 20, 'tune_testset': False, 'tune_pack': '{"reg": {"min": 10, "max": 1000, "step": 10}}', 'algo_name': 'ease', 'val_method': 'tsbr', 'test_method': 'tsbr', 'fold_num': 1, 'val_size': 0.1, 'test_size': 0.2, 'topk': 1, 'cand_num': 200, 'sample_method': 'uniform', 'sample_ratio': 0, 'num_ng': 4, 'batch_size': 256, 'loss_type': 'BPR', 'init_method': 'default', 'optimizer': 'default', 'early_stop': False, 'data_path': 'data/', 'res_path': None, 'dataset': 'amazon-electronic', 'prepro': 'origin', 'level': 'ui', 'UID_NAME': 'user', 'IID_NAME': 'item', 'INTER_NAME': 'rating', 'TID_NAME': 'timestamp', 'binary_inter': True, 'positive_threshold': None, 'metrics': ['recall', 'mrr', 'ndcg', 'hit', 'precision'], 'reg': 200.0}
# 17 Apr 05:20 INFO - Current data path is: data/amazon-electronic/, make sure you put the right raw data into it...
# ...

# %%
# %%shell
# python /content/daisyRec/run_examples/test.py --algo_name=ease --dataset=amazon-electronic --prepro=origin --topk=100 --epochs=100 --test_size=0.2 --val_size=0.1 --cand_num=200 --test_method=tsbr --val_method=tsbr --reg=820
# Out:
# 17 Apr 05:59 INFO - {'gpu': '0', 'seed': 2022, 'reproducibility': True, 'state': None, 'optimization_metric': 'ndcg', 'hyperopt_trail': 30, 'tune_testset': False, 'tune_pack': '{}', 'algo_name': 'ease', 'val_method': 'tsbr', 'test_method': 'tsbr', 'fold_num': 1, 'val_size': 0.1, 'test_size': 0.2, 'topk': 100, 'cand_num': 200, 'sample_method': 'uniform', 'sample_ratio': 0, 'num_ng': 4, 'batch_size': 256, 'loss_type': 'BPR', 'init_method': 'default', 'optimizer': 'default', 'early_stop': False, 'data_path': 'data/', 'res_path': None, 'dataset': 'amazon-electronic', 'prepro': 'origin', 'level': 'ui', 'UID_NAME': 'user', 'IID_NAME': 'item', 'INTER_NAME': 'rating', 'TID_NAME': 'timestamp', 'binary_inter': True, 'positive_threshold': None, 'metrics': ['recall', 'mrr', 'ndcg', 'hit', 'precision'], 'reg': 820.0}
# 17 Apr 05:59 INFO - Current data path is: data/amazon-electronic/, make sure you put the right raw data into it...
# ...

# %% [markdown]
# **Movie Lens - 100K dataset**

# %%
# %%shell
# python /content/daisyRec/run_examples/tune.py --algo_name=ease --dataset=ml-100k --prepro=origin --topk=50 --epochs=50 --test_size=0.2 --val_size=0.1 --cand_num=1000 --test_method=tsbr --val_method=tsbr --reg=200
# Out:
# 17 Apr 06:12 INFO - {'gpu': '0', 'seed': 2022, 'reproducibility': True, 'state': None, 'optimization_metric': 'ndcg', 'hyperopt_trail': 30, 'tune_testset': False, 'tune_pack': '{}', 'algo_name': 'ease', 'val_method': 'tsbr', 'test_method': 'tsbr', 'fold_num': 1, 'val_size': 0.1, 'test_size': 0.2, 'topk': 50, 'cand_num': 1000, 'sample_method': 'uniform', 'sample_ratio': 0, 'num_ng': 4, 'batch_size': 256, 'loss_type': 'BPR', 'init_method': 'default', 'optimizer': 'default', 'early_stop': False, 'data_path': 'data/', 'res_path': None, 'dataset': 'ml-100k', 'prepro': 'origin', 'level': 'ui', 'UID_NAME': 'user', 'IID_NAME': 'item', 'INTER_NAME': 'rating', 'TID_NAME': 'timestamp', 'binary_inter': True, 'positive_threshold': None, 'metrics': ['recall', 'mrr', 'ndcg', 'hit', 'precision'], 'reg': 200.0}
# 17 Apr 06:12 INFO - Current data path is: data/ml-100k/, make sure you put the right raw data into it...
# 17 Apr 06:12 INFO - Finish loading [ml-100k]-[origin] dataset
# ...

# %%
# %%shell
# python /content/daisyRec/run_examples/test.py --algo_name=ease --dataset=ml-100k --prepro=origin --topk=50 --epochs=50 --test_size=0.2 --val_size=0.1 --cand_num=1000 --test_method=tsbr --val_method=tsbr --reg=200
# Out:
# 17 Apr 06:17 INFO - {'gpu': '0', 'seed': 2022, 'reproducibility': True, 'state': None, 'optimization_metric': 'ndcg', 'hyperopt_trail': 30, 'tune_testset': False, 'tune_pack': '{}', 'algo_name': 'ease', 'val_method': 'tsbr', 'test_method': 'tsbr', 'fold_num': 1, 'val_size': 0.1, 'test_size': 0.2, 'topk': 50, 'cand_num': 1000, 'sample_method': 'uniform', 'sample_ratio': 0, 'num_ng': 4, 'batch_size': 256, 'loss_type': 'BPR', 'init_method': 'default', 'optimizer': 'default', 'early_stop': False, 'data_path': 'data/', 'res_path': None, 'dataset': 'ml-100k', 'prepro': 'origin', 'level': 'ui', 'UID_NAME': 'user', 'IID_NAME': 'item', 'INTER_NAME': 'rating', 'TID_NAME': 'timestamp', 'binary_inter': True, 'positive_threshold': None, 'metrics': ['recall', 'mrr', 'ndcg', 'hit', 'precision'], 'reg': 200.0}
# 17 Apr 06:17 INFO - Current data path is: data/ml-100k/, make sure you put the right raw data into it...
# 17 Apr 06:17 INFO - Finish loading [ml-100k]-[origin] dataset
# ...

# %%
# %%shell
# python /content/daisyRec/run_examples/tune.py --optimization_metric=ndcg --hyperopt_trail=20 --algo_name=ease --dataset=ml-1m --prepro=origin --topk=50 --epochs=100 --test_size=0.2 --val_size=0.1 --cand_num=1000 --test_method=tsbr --val_method=tsbr --tune_pack='{"reg": {"min": 10, "max": 3000, "step": null}}'
# Out:
# 17 Apr 06:24 INFO - {'gpu': '0', 'seed': 2022, 'reproducibility': True, 'state': None, 'optimization_metric': 'ndcg', 'hyperopt_trail': 20, 'tune_testset': False, 'tune_pack': '{"reg": {"min": 10, "max": 3000, "step": null}}', 'algo_name': 'ease', 'val_method': 'tsbr', 'test_method': 'tsbr', 'fold_num': 1, 'val_size': 0.1, 'test_size': 0.2, 'topk': 50, 'cand_num': 1000, 'sample_method': 'uniform', 'sample_ratio': 0, 'num_ng': 4, 'batch_size': 256, 'loss_type': 'BPR', 'init_method': 'default', 'optimizer': 'default', 'early_stop': False, 'data_path': 'data/', 'res_path': None, 'dataset': 'ml-1m', 'prepro': 'origin', 'level': 'ui', 'UID_NAME': 'user', 'IID_NAME': 'item', 'INTER_NAME': 'rating', 'TID_NAME': 'timestamp', 'binary_inter': True, 'positive_threshold': None, 'metrics': ['recall', 'mrr', 'ndcg', 'hit', 'precision'], 'reg': 200.0}
# 17 Apr 06:24 INFO - Current data path is: data/ml-1m/, make sure you put the right raw data into it...
# ...

# %%
# %%shell
# python /content/daisyRec/run_examples/test.py --algo_name=ease --dataset=ml-1m --prepro=origin --topk=50 --epochs=100 --test_size=0.2 --val_size=0.1 --cand_num=1000 --test_method=tsbr --val_method=tsbr --reg=3000
# Out:
# 17 Apr 06:45 INFO - {'gpu': '0', 'seed': 2022, 'reproducibility': True, 'state': None, 'optimization_metric': 'ndcg', 'hyperopt_trail': 30, 'tune_testset': False, 'tune_pack': '{}', 'algo_name': 'ease', 'val_method': 'tsbr', 'test_method': 'tsbr', 'fold_num': 1, 'val_size': 0.1, 'test_size': 0.2, 'topk': 50, 'cand_num': 1000, 'sample_method': 'uniform', 'sample_ratio': 0, 'num_ng': 4, 'batch_size': 256, 'loss_type': 'BPR', 'init_method': 'default', 'optimizer': 'default', 'early_stop': False, 'data_path': 'data/', 'res_path': None, 'dataset': 'ml-1m', 'prepro': 'origin', 'level': 'ui', 'UID_NAME': 'user', 'IID_NAME': 'item', 'INTER_NAME': 'rating', 'TID_NAME': 'timestamp', 'binary_inter': True, 'positive_threshold': None, 'metrics': ['recall', 'mrr', 'ndcg', 'hit', 'precision'], 'reg': 3000.0}
# 17 Apr 06:45 INFO - Current data path is: data/ml-1m/, make sure you put the right raw data into it...
# 17 Apr 06:45 INFO - Finish loading [ml-1m]-[origin] dataset
# ...
